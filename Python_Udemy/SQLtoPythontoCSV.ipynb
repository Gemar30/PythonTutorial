# %%
import pandas as pd

# %%
df = pd.read_csv('airlines_data_part.csv')

# %%
df.head()
# Out:
#          passenger_name  day  month departure_city arrival_city     sales
# 0        VIKTOR BORISOV   21      6      Astrakhan       Moscow   52000.0
# 1        VIKTOR BORISOV   21      6         Moscow    Astrakhan   52000.0
# 2  ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow   52000.0
# 3  ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan   52000.0
# 4     LYUDMILA POTAPOVA   21      6         Moscow   Khabarovsk  178800.0

# %%
df.columns
# Out:
# Index(['passenger_name', 'day', 'month', 'departure_city', 'arrival_city',
#        'sales'],
#       dtype='object')

# %%
df.passenger_name
# Out:
# 0                VIKTOR BORISOV
# 1                VIKTOR BORISOV
# 2          ALEKSANDRA KUZNECOVA
# 3          ALEKSANDRA KUZNECOVA
# 4             LYUDMILA POTAPOVA
#                    ...
# 1016769        ALEKSANDR ZAYCEV
# 1016770           VASILIY FOMIN
# 1016771         VALERIY MOISEEV
# 1016772         VALERIY MOISEEV
# 1016773           VASILIY FOMIN
# Name: passenger_name, Length: 1016774, dtype: object

# %%
df
# Out:
#                passenger_name  day  month departure_city arrival_city  \
# 0              VIKTOR BORISOV   21      6      Astrakhan       Moscow
# 1              VIKTOR BORISOV   21      6         Moscow    Astrakhan
# 2        ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow
# 3        ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan
# 4           LYUDMILA POTAPOVA   21      6         Moscow   Khabarovsk
# ...                       ...  ...    ...            ...          ...
# 1016769      ALEKSANDR ZAYCEV   15      8         Moscow      Bryansk
# 1016770         VASILIY FOMIN   15      8        Bryansk       Moscow
# 1016771       VALERIY MOISEEV   15      8         Moscow      Bryansk
# 1016772       VALERIY MOISEEV   15      8        Bryansk       Moscow
# 1016773         VASILIY FOMIN   15      8         Moscow      Bryansk
#
#              sales
# 0          52000.0
# 1          52000.0
# 2          52000.0
# 3          52000.0
# 4         178800.0
# ...            ...
# 1016769  1185800.0
# 1016770  1185800.0
# 1016771  1185800.0
# 1016772  1185800.0
# 1016773  1185800.0
#
# [1016774 rows x 6 columns]

# %%
df1 = df[['passenger_name','day','arrival_city']]

# %%
df1
# Out:
#                passenger_name  day arrival_city
# 0              VIKTOR BORISOV   21       Moscow
# 1              VIKTOR BORISOV   21    Astrakhan
# 2        ALEKSANDRA KUZNECOVA   21       Moscow
# 3        ALEKSANDRA KUZNECOVA   21    Astrakhan
# 4           LYUDMILA POTAPOVA   21   Khabarovsk
# ...                       ...  ...          ...
# 1016769      ALEKSANDR ZAYCEV   15      Bryansk
# 1016770         VASILIY FOMIN   15       Moscow
# 1016771       VALERIY MOISEEV   15      Bryansk
# 1016772       VALERIY MOISEEV   15       Moscow
# 1016773         VASILIY FOMIN   15      Bryansk
#
# [1016774 rows x 3 columns]

# %%
df.tail()
# Out:
#            passenger_name  day  month departure_city arrival_city      sales
# 1016769  ALEKSANDR ZAYCEV   15      8         Moscow      Bryansk  1185800.0
# 1016770     VASILIY FOMIN   15      8        Bryansk       Moscow  1185800.0
# 1016771   VALERIY MOISEEV   15      8         Moscow      Bryansk  1185800.0
# 1016772   VALERIY MOISEEV   15      8        Bryansk       Moscow  1185800.0
# 1016773     VASILIY FOMIN   15      8         Moscow      Bryansk  1185800.0

# %%
display(df.iloc[6])
# Out:
# passenger_name    LYUDMILA POTAPOVA
# day                              21
# month                             6
# departure_city               Moscow
# arrival_city            Novosibirsk
# sales                      178800.0
# Name: 6, dtype: object

# %%
df.rank()
# Out:
#          passenger_name       day     month  departure_city  arrival_city  \
# 0              900108.5  766592.0   13139.5         18245.0      411802.5
# 1              900108.5  766592.0   13139.5        413851.0       18638.5
# 2               59881.0  766592.0   13139.5         18245.0      411802.5
# 3               59881.0  766592.0   13139.5        413851.0       18638.5
# 4              476623.0  766592.0   13139.5        413851.0      144140.0
# ...                 ...       ...       ...             ...           ...
# 1016769         55026.0  625286.0  842876.5        413851.0       47525.0
# 1016770        881570.0  625286.0  842876.5         46857.0      411802.5
# 1016771        871486.5  625286.0  842876.5        413851.0       47525.0
# 1016772        871486.5  625286.0  842876.5         46857.0      411802.5
# 1016773        881570.0  625286.0  842876.5        413851.0       47525.0
#
#              sales
# 0         327804.5
# 1         327804.5
# 2         327804.5
# 3         327804.5
# 4         861658.5
# ...            ...
# 1016769  1016721.5
# 1016770  1016721.5
# 1016771  1016721.5
# 1016772  1016721.5
# 1016773  1016721.5
#
# [1016774 rows x 6 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                passenger_name  day  month departure_city arrival_city  \
# 0              VIKTOR BORISOV   21      6      Astrakhan       Moscow
# 1              VIKTOR BORISOV   21      6         Moscow    Astrakhan
# 2        ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow
# 3        ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan
# 4           LYUDMILA POTAPOVA   21      6         Moscow   Khabarovsk
# ...                       ...  ...    ...            ...          ...
# 1016769      ALEKSANDR ZAYCEV   15      8         Moscow      Bryansk
# 1016770         VASILIY FOMIN   15      8        Bryansk       Moscow
# 1016771       VALERIY MOISEEV   15      8         Moscow      Bryansk
# 1016772       VALERIY MOISEEV   15      8        Bryansk       Moscow
# 1016773         VASILIY FOMIN   15      8         Moscow      Bryansk
#
#              sales
# 0          52000.0
# 1          52000.0
# 2          52000.0
# 3          52000.0
# 4         178800.0
# ...            ...
# 1016769  1185800.0
# 1016770  1185800.0
# 1016771  1185800.0
# 1016772  1185800.0
# 1016773  1185800.0
#
# [1016774 rows x 6 columns]>

# %%
import webbrowser

# %%
website = 'https://www.facebook.com/'
webbrowser.open(website)
# Out:
# True
