# %%
import pandas as pd

# %%
df = pd.read_csv('airlines_data_part.csv')

# %%
df
# Out:
#                passenger_name  day  month departure_city arrival_city  \
# 0              VIKTOR BORISOV   21      6      Astrakhan       Moscow
# 1              VIKTOR BORISOV   21      6         Moscow    Astrakhan
# 2        ALEKSANDRA KUZNECOVA   21      6      Astrakhan       Moscow
# 3        ALEKSANDRA KUZNECOVA   21      6         Moscow    Astrakhan
# 4           LYUDMILA POTAPOVA   21      6         Moscow   Khabarovsk
# ...                       ...  ...    ...            ...          ...
# 1016769      ALEKSANDR ZAYCEV   15      8         Moscow      Bryansk
# 1016770         VASILIY FOMIN   15      8        Bryansk       Moscow
# 1016771       VALERIY MOISEEV   15      8         Moscow      Bryansk
# 1016772       VALERIY MOISEEV   15      8        Bryansk       Moscow
# 1016773         VASILIY FOMIN   15      8         Moscow      Bryansk
#
#              sales
# 0          52000.0
# 1          52000.0
# 2          52000.0
# 3          52000.0
# 4         178800.0
# ...            ...
# 1016769  1185800.0
# 1016770  1185800.0
# 1016771  1185800.0
# 1016772  1185800.0
# 1016773  1185800.0
#
# [1016774 rows x 6 columns]

# %%
df.shape
# Out:
# (1016774, 6)

# %%
df.size
# Out:
# 6100644

# %%
round(df.sales.mean(),2)
# Out:
# 106168.85

# %%
df1 = df.sample(15)

# %%
df1
# Out:
#             passenger_name  day  month  departure_city       arrival_city  \
# 660298   VYACHESLAV PAVLOV   31      7       Syktyvkar      Yekaterinburg
# 559119   ALEKSANDR SAVELEV   26      7         Irkutsk              Kazan
# 988935    ALEKSANDR ZHUKOV   14      8          Moscow            Bryansk
# 753192   VALENTINA IVANOVA    4      8          Moscow  Yuzhno-Sakhalinsk
# 453765  EKATERINA MAKAROVA   21      7          Moscow              Sochi
# 179217      OLGA TIKHONOVA    9      7           Sochi             Moscow
# 116604   ANATOLIY MEDVEDEV    6      7         Izhevsk             Moscow
# 172117   VIKTORIYA RYABOVA    8      7          Kurgan        Krasnoyarsk
# 483584     VLADIMIR PAVLOV   23      7          Moscow       Petrozavodsk
# 670371       OLESYA GUSEVA    1      8          Moscow          Krasnodar
# 407901       ALEKSEY FOMIN   19      7         Vorkuta               Omsk
# 736492         NINA POPOVA    4      8     Chelyabinsk               Perm
# 318297    VLADIMIR FEDOROV   15      7  Nizhnevartovsk             Moscow
# 464638      KIRILL TARASOV   22      7     Chelyabinsk               Perm
# 145358     DMITRIY KAZAKOV    7      7  Nizhnevartovsk          Sovetskiy
#
#            sales
# 660298   92800.0
# 559119  184300.0
# 988935  247000.0
# 753192  266400.0
# 453765  222000.0
# 179217   27200.0
# 116604   31800.0
# 172117  141100.0
# 483584   50600.0
# 670371   23200.0
# 407901  138000.0
# 736492   32200.0
# 318297   92400.0
# 464638   63700.0
# 145358   78300.0

# %%
import matplotlib.pyplot as plt
sales = df1['sales']
months = df1['month']
plt.bar(months, sales)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df2 = df.sample(30)

# %%
df2
# Out:
#              passenger_name  day  month    departure_city     arrival_city  \
# 232188     ALEKSANDR OSIPOV   11      7            Moscow        Sovetskiy
# 920438     ZINAIDA MIRONOVA   12      8            Moscow       Cheboksary
# 387944       DENIS KUZNECOV   18      7           Irkutsk            Kazan
# 914345     NATALYA SOLOVEVA   11      8           Norilsk    Yekaterinburg
# 206832     GALINA NIKOLAEVA   10      7       Arkhangelsk           Moscow
# 502865        YURIY SERGEEV   24      7       Makhachkala           Moscow
# 700405    VASILIY MIKHAYLOV    2      8           Vorkuta             Omsk
# 33120         RAISA FROLOVA    1      7           Norilsk    Yekaterinburg
# 108546      NIKOLAY SEMENOV    5      7            Moscow           Kurgan
# 550845   SVETLANA RODIONOVA   26      7            Moscow  Mineralnye Vody
# 483033        DANIL CHERNOV   23      7            Moscow              Ufa
# 403958       DANIL AFANASEV   19      7    Nizhnevartovsk        Sovetskiy
# 818583         YURIY ZAYCEV    7      8            Surgut        Sovetskiy
# 138595      TAMARA MAKAROVA    7      7             Kirov            Kazan
# 445955         ANDREY POPOV   21      7            Rostov            Sochi
# 957552        IGOR KUZNECOV   13      8              Perm           Moscow
# 161943           ARTEM ILIN    8      7            Samara           Moscow
# 668228       YULIYA IVANOVA   31      7        Khabarovsk           Anadyr
# 245727       KIRILL MATVEEV   12      7     Yekaterinburg           Moscow
# 723570     TATYANA BORISOVA    3      8             Sochi           Moscow
# 171921      EVGENIY VASILEV    8      7       Novosibirsk           Abakan
# 905791      INESSA SMIRNOVA   11      8            Moscow           Samara
# 998730       RUSTEM ANTONOV   15      8  Nizhniy Novgorod             Perm
# 957695         IVAN BORISOV   13      8            Moscow       Khabarovsk
# 284032        IVAN KUZNECOV   14      7            Moscow          Saransk
# 747396       ELENA SOROKINA    4      8            Samara            Sochi
# 191995      VLADIMIR VOLKOV    9      7        Khabarovsk           Moscow
# 462911    ALEKSANDR ROMANOV   22      7              Perm           Moscow
# 192103   VALENTINA DAVYDOVA    9      7             Kirov            Kazan
# 245509  ALEKSEY ALEKSANDROV   12      7            Moscow          Bryansk
#
#            sales
# 232188   87800.0
# 920438   37800.0
# 387944  170000.0
# 914345  344100.0
# 206832   60600.0
# 502865   40800.0
# 700405   69500.0
# 33120    77000.0
# 108546  139300.0
# 550845   68300.0
# 483033   47100.0
# 403958   92700.0
# 818583  193900.0
# 138595   37500.0
# 445955   81800.0
# 957552  120600.0
# 161943   49100.0
# 668228  357600.0
# 245727   36800.0
# 723570   84100.0
# 171921  138000.0
# 905791   98100.0
# 998730   46400.0
# 957695  123000.0
# 284032   10800.0
# 747396  111000.0
# 191995  123000.0
# 462911   54700.0
# 192103  124500.0
# 245509   35800.0

# %%
import matplotlib.pyplot as plt
sales = df2['sales']
months = df2['month']
plt.bar(months, sales)
plt.xticks(months, rotation='horizontal', size=10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df3 = df.sample(500)

# %%
import matplotlib.pyplot as plt
sales = df3['sales']
months = df3['month']
plt.bar(months,sales)
plt.xticks(months, rotation ='horizontal', size=10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()

# %%
df4 = df.sample(1000)

# %%
import matplotlib.pyplot as plt
sales = df4['sales']
months = df4['month']
plt.bar(months,sales)
plt.xticks(months, rotation ='horizontal', size=10)
plt.ylabel('Sales')
plt.xlabel('Summer Months')
plt.show()
